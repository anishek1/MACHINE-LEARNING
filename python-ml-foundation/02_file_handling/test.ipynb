# %%
with open('text.txt','r') as file:
 content=file.read()
print(content)
# Out:
# hi i am anishekh prasad
# i am from banarhat
# i am 20 years old
# i am learning python
# and lets see!!

# %%
with open('text.txt','r') as file:
    for line in file:
        print(line.strip())
# Out:
# hi i am anishekh prasad
# i am from banarhat
# i am 20 years old
# i am learning python
# and lets see!!

# %%
##write in a file
with open ('text.txt','w') as file:
    file.write('hello\n')

# %%
##write without overrriding
with open('text.txt','a') as file:
    file.write('anishrekj')

# %%
##create a new directory
import os
new_directory="package"
os.mkdir(new_directory)
print(f"directory '{new_directory}' create")
# Out:
# directory 'package' create

# %%
items=os.listdir('.')
print(items)
# Out:
# ['package', 'test.ipynb', 'text.txt']
